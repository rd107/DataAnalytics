# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
data=pd.read_csv("survey.csv")

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data['Gender'].replace('M','Male',inplace=True)

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44    Male   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data['Gender'].replace("male","Male",inplace=True)

# %%
print(data['Gender'])
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1254      Male
# 1255      Male
# 1256      Male
# 1257         f
# 1258      Male
# Name: Gender, Length: 1259, dtype: object

# %%
data['Gender'].replace("f","Female",inplace=True)

# %%
data['Gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1254      Male
# 1255      Male
# 1256      Male
# 1257    Female
# 1258      Male
# Name: Gender, Length: 1259, dtype: object

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data['Gender'].replace("female","Female",inplace=True)
data['Gender'].replace("m","Male",inplace=True)
data['Gender'].replace("Male-ish","Male",inplace=True)
data['Gender'].replace("maile","Male",inplace=True)
data['Gender'].replace("Trans-female","Female",inplace=True)
data['Gender'].replace("Cis Female","Female",inplace=True)
data['Gender'].replace("F","Female",inplace=True)
data['Gender'].replace("something kinda male?","Male",inplace=True)
data['Gender'].replace("Cis Male","Male",inplace=True)
data['Gender'].replace("Woman","Female",inplace=True)
data['Gender'].replace("Mal","Male",inplace=True)
data['Gender'].replace("Male (CIS)","Male",inplace=True)
data['Gender'].replace("queer/she/they","Female",inplace=True)
data['Gender'].replace("Femake","Female",inplace=True)
data['Gender'].replace("woman","Female",inplace=True)
data['Gender'].replace("make","Male",inplace=True)
data['Gender'].replace("Female ","Female",inplace=True)
data['Gender'].replace("Female ","Female",inplace=True)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'non-binary', 'Make', 'Nah', 'All', 'Enby',
#        'fluid', 'Genderqueer', 'Androgyne', 'Agender', 'cis-female/femme',
#        'Guy (-ish) ^_^', 'male leaning androgynous', 'Male ', 'Man',
#        'Trans woman', 'msle', 'Neuter', 'Female (trans)', 'queer',
#        'Female (cis)', 'Mail', 'cis male', 'A little about you', 'Malr',
#        'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data['Gender'].replace("non-binary","Transgender",inplace=True)
data['Gender'].replace("Make","Male",inplace=True)
data['Gender'].replace("All","Transgender",inplace=True)
data['Gender'].replace("Enby","Transgender",inplace=True)
data['Gender'].replace("fluid","Transgender",inplace=True)
data['Gender'].replace("Genderqueer","Transgender",inplace=True)
data['Gender'].replace("Androgyne","Transgender",inplace=True)
data['Gender'].replace("Agender","Transgender",inplace=True)
data['Gender'].replace("cis-female/femme","Female",inplace=True)
data['Gender'].replace("cis-female/femme","Female",inplace=True)
data['Gender'].replace("Guy (-ish) ^_^","Male",inplace=True)
data['Gender'].replace("male leaning androgynous","Male",inplace=True)
data['Gender'].replace("Male ","Male",inplace=True)
data['Gender'].replace("Man","Male",inplace=True)
data['Gender'].replace("Trans woman","Female",inplace=True)
data['Gender'].replace("msle","Male",inplace=True)
data['Gender'].replace("Neuter","Transgender",inplace=True)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Transgender', 'Nah', 'Female (trans)', 'queer',
#        'Female (cis)', 'Mail', 'cis male', 'A little about you', 'Malr',
#        'p', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data['Gender'].replace("Female (trans)","Female",inplace=True)
data['Gender'].replace("queer","Queer",inplace=True)
data['Gender'].replace("Female (cis)","Female",inplace=True)
data['Gender'].replace("Mail","Male",inplace=True)
data['Gender'].replace("cis male","Male",inplace=True)
data['Gender'].replace("Malr","Male",inplace=True)
data['Gender'].replace("femail","Female",inplace=True)
data['Gender'].replace("Cis Man","Male",inplace=True)
data['Gender'].replace("ostensibly male","Male",inplace=True)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Transgender', 'Nah', 'Queer',
#        'A little about you', 'p',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data[data['Gender']=="Nah"]
# Out:
#                Timestamp  Age Gender        Country state self_employed  \
# 387  2014-08-27 15:24:22   29    Nah  United States    CA           Yes
#
#     family_history treatment work_interfere no_employees  ...           leave  \
# 387            Yes       Yes      Sometimes          1-5  ...  Very difficult
#
#     mental_health_consequence phys_health_consequence     coworkers  \
# 387                       Yes                      No  Some of them
#
#     supervisor mental_health_interview phys_health_interview  \
# 387         No                      No                 Maybe
#
#     mental_vs_physical obs_consequence comments
# 387                 No              No      NaN
#
# [1 rows x 27 columns]

# %%
data[data.duplicated]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, Country, state, self_employed, family_history, treatment, work_interfere, no_employees, remote_work, tech_company, benefits, care_options, wellness_program, seek_help, anonymity, leave, mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview, mental_vs_physical, obs_consequence, comments]
# Index: []
#
# [0 rows x 27 columns]

# %%
# data.iloc([[387]])
data[data['Gender']=="Nah"]
# Out:
#                Timestamp  Age Gender        Country state self_employed  \
# 387  2014-08-27 15:24:22   29    Nah  United States    CA           Yes
#
#     family_history treatment work_interfere no_employees  ...           leave  \
# 387            Yes       Yes      Sometimes          1-5  ...  Very difficult
#
#     mental_health_consequence phys_health_consequence     coworkers  \
# 387                       Yes                      No  Some of them
#
#     supervisor mental_health_interview phys_health_interview  \
# 387         No                      No                 Maybe
#
#     mental_vs_physical obs_consequence comments
# 387                 No              No      NaN
#
# [1 rows x 27 columns]

# %%
data=data.drop(387)

# %%
data[data['Gender']=="Nah"]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, Country, state, self_employed, family_history, treatment, work_interfere, no_employees, remote_work, tech_company, benefits, care_options, wellness_program, seek_help, anonymity, leave, mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview, mental_vs_physical, obs_consequence, comments]
# Index: []
#
# [0 rows x 27 columns]

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Transgender', 'Queer', 'A little about you',
#        'p', 'ostensibly male, unsure what that really means'],
#       dtype=object)

# %%
data[data['Gender']=="A little about you"]
# Out:
#                Timestamp  Age              Gender       Country state  \
# 989  2014-08-29 09:10:58    8  A little about you  Bahamas, The    IL
#
#     self_employed family_history treatment work_interfere no_employees  ...  \
# 989           Yes            Yes       Yes          Often          1-5  ...
#
#          leave mental_health_consequence phys_health_consequence coworkers  \
# 989  Very easy                       Yes                     Yes       Yes
#
#     supervisor mental_health_interview phys_health_interview  \
# 989        Yes                     Yes                   Yes
#
#     mental_vs_physical obs_consequence comments
# 989                Yes             Yes
#
# [1 rows x 27 columns]

# %%
data=data.drop(989)

# %%
data[data['Gender']=="A little about you"]
# Out:
# Empty DataFrame
# Columns: [Timestamp, Age, Gender, Country, state, self_employed, family_history, treatment, work_interfere, no_employees, remote_work, tech_company, benefits, care_options, wellness_program, seek_help, anonymity, leave, mental_health_consequence, phys_health_consequence, coworkers, supervisor, mental_health_interview, phys_health_interview, mental_vs_physical, obs_consequence, comments]
# Index: []
#
# [0 rows x 27 columns]

# %%
data[data['Gender']=="p"]
# Out:
#                 Timestamp  Age Gender        Country state self_employed  \
# 1127  2014-08-30 20:55:11   -1      p  United States    AL           Yes
#
#      family_history treatment work_interfere no_employees  ...      leave  \
# 1127            Yes       Yes          Often          1-5  ...  Very easy
#
#      mental_health_consequence phys_health_consequence coworkers supervisor  \
# 1127                       Yes                     Yes       Yes        Yes
#
#      mental_health_interview phys_health_interview mental_vs_physical  \
# 1127                     Yes                   Yes                Yes
#
#      obs_consequence            comments
# 1127             Yes  password: testered
#
# [1 rows x 27 columns]

# %%
data=data.drop(1127)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Transgender', 'Queer',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
data.Gender.value_counts()
# Out:
# Male                                              994
# Female                                            252
# Transgender                                         8
# Queer                                               1
# ostensibly male, unsure what that really means      1
# Name: Gender, dtype: int64

# %%
data.replace("ostensibly male, unsure what that really means","Male",inplace=True)

# %%
data['Gender'].unique()
# Out:
# array(['Female', 'Male', 'Transgender', 'Queer'], dtype=object)

# %%
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44    Male   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data.shape
# Out:
# (1256, 27)

# %%
data.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                         515
# self_employed                  18
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1094
# dtype: int64

# %%
data.dtypes
# Out:
# Timestamp                    object
# Age                           int64
# Gender                       object
# Country                      object
# state                        object
# self_employed                object
# family_history               object
# treatment                    object
# work_interfere               object
# no_employees                 object
# remote_work                  object
# tech_company                 object
# benefits                     object
# care_options                 object
# wellness_program             object
# seek_help                    object
# anonymity                    object
# leave                        object
# mental_health_consequence    object
# phys_health_consequence      object
# coworkers                    object
# supervisor                   object
# mental_health_interview      object
# phys_health_interview        object
# mental_vs_physical           object
# obs_consequence              object
# ...

# %%
data['self_employed']=data['self_employed'].fillna("NA")
data.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL            NA
# 1  2014-08-27 11:29:37   44    Male   United States    IN            NA
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN            NA
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN            NA
# 4  2014-08-27 11:30:22   31    Male   United States    TX            NA
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
data['state']=data['state'].fillna("NA")

# %%
data.isna().sum()
# Out:
# Timestamp                       0
# Age                             0
# Gender                          0
# Country                         0
# state                           0
# self_employed                   0
# family_history                  0
# treatment                       0
# work_interfere                264
# no_employees                    0
# remote_work                     0
# tech_company                    0
# benefits                        0
# care_options                    0
# wellness_program                0
# seek_help                       0
# anonymity                       0
# leave                           0
# mental_health_consequence       0
# phys_health_consequence         0
# coworkers                       0
# supervisor                      0
# mental_health_interview         0
# phys_health_interview           0
# mental_vs_physical              0
# obs_consequence                 0
# comments                     1094
# dtype: int64

# %%
data['work_interfere']=data['work_interfere'].fillna("NA")
data['comments']=data['comments'].fillna("NA")

# %%
data.isna().sum()
# Out:
# Timestamp                    0
# Age                          0
# Gender                       0
# Country                      0
# state                        0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# comments                     0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis
